# %%
### Thomas Drage

import pandas as pd
# %matplotlib inline
import numpy as np

# %%
dateparse = lambda dates: [pd.datetime.strptime(x, '%m/%d/%y %H:%M') for x in dates]

# Import the CSV file
df = pd.read_csv("out.csv", parse_dates=["Date"], date_parser=dateparse)

# %%
df
# Out:
#                     Date      Case                    Category  \
# 0    2019-05-08 00:22:00       NaN                TRAFFIC STOP
# 1    2019-05-08 00:43:00       NaN                TRAFFIC STOP
# 2    2019-05-08 01:06:00       NaN                TRAFFIC STOP
# 3    2019-05-08 01:20:00       NaN               WELFARE CHECK
# 4    2019-05-08 01:23:00       NaN            SUSPICIOUS EVENT
# 5    2019-05-08 05:34:00       NaN             PEDESTRIAN STOP
# 6    2019-05-08 06:11:00       NaN              OUTSIDE ASSIST
# 7    2019-05-08 06:20:00       NaN           MAINTENANCE ISSUE
# 8    2019-05-08 07:46:00       NaN            SUSPICIOUS EVENT
# 9    2019-05-08 08:23:00       NaN               WELFARE CHECK
# 10   2019-05-08 09:50:00       NaN          ALL OTHER OFFENSES
# 11   2019-05-08 09:51:00  19-01246               LARCENY/THEFT
# 12   2019-05-08 10:16:00       NaN      VEHICLE CODE VIOLATION
# 13   2019-05-08 10:51:00  19-01245          ALL OTHER OFFENSES
# 14   2019-05-08 12:40:00       NaN      VEHICLE CODE VIOLATION
# 15   2019-05-08 13:08:00       NaN               WELFARE CHECK
# 16   2019-05-08 13:19:00       NaN            SUSPICIOUS EVENT
# 17   2019-05-08 13:42:00       NaN                TRAFFIC STOP
# 18   2019-05-08 13:55:00       NaN               WELFARE CHECK
# 19   2019-05-08 14:23:00       NaN               WELFARE CHECK
# 20   2019-05-08 15:00:00       NaN          ALL OTHER OFFENSES
# 21   2019-05-08 15:01:00  19-01247               LARCENY/THEFT
# 22   2019-05-08 15:05:00       NaN               WELFARE CHECK
# 23   2019-05-08 15:24:00  19-01249  FORGERY AND COUNTERFEITING
# 24   2019-05-08 15:26:00       NaN              OUTSIDE ASSIST
# 25   2019-05-08 16:05:00       NaN               LARCENY/THEFT
# 26   2019-05-08 16:13:00  19-01248               LARCENY/THEFT
# 27   2019-05-08 16:50:00       NaN               WELFARE CHECK
# 28   2019-05-08 17:31:00       NaN               WELFARE CHECK
# 29   2019-05-08 17:52:00       NaN      VEHICLE CODE VIOLATION
# ...                  ...       ...                         ...
# 2060 2019-07-08 02:15:00       NaN             PEDESTRIAN STOP
# 2061 2019-07-08 07:00:00  19-01771          ALL OTHER OFFENSES
# 2062 2019-07-08 08:10:00       NaN               MISC. SERVICE
# 2063 2019-07-08 08:27:00       NaN  FORGERY AND COUNTERFEITING
# 2064 2019-07-08 08:45:00       NaN            SUSPICIOUS EVENT
# 2065 2019-07-08 09:09:00  19-01772               LARCENY/THEFT
# 2066 2019-07-08 10:26:00  19-01773          WEAPONS VIOLATIONS
# 2067 2019-07-08 10:44:00       NaN            SUSPICIOUS EVENT
# 2068 2019-07-08 11:46:00       NaN                TRAFFIC STOP
# 2069 2019-07-08 11:53:00       NaN               WELFARE CHECK
# 2070 2019-07-08 12:44:00       NaN               WELFARE CHECK
# 2071 2019-07-08 14:11:00  19-01775          ALL OTHER OFFENSES
# 2072 2019-07-08 14:22:00  19-01774               MISC. SERVICE
# 2073 2019-07-08 14:43:00  19-01776               LARCENY/THEFT
# 2074 2019-07-08 14:59:00  19-01778               LARCENY/THEFT
# 2075 2019-07-08 15:47:00       NaN                TRAFFIC STOP
# 2076 2019-07-08 15:54:00       NaN                       ALARM
# 2077 2019-07-08 16:34:00  19-01777            SUSPICIOUS EVENT
# 2078 2019-07-08 17:07:00       NaN               WELFARE CHECK
# 2079 2019-07-08 17:08:00       NaN            SUSPICIOUS EVENT
# 2080 2019-07-08 18:05:00  19-01782               MISC. SERVICE
# 2081 2019-07-08 18:12:00       NaN            SUSPICIOUS EVENT
# 2082 2019-07-08 18:24:00       NaN             PEDESTRIAN STOP
# 2083 2019-07-08 19:13:00       NaN           MAINTENANCE ISSUE
# 2084 2019-07-08 19:20:00       NaN          ALL OTHER OFFENSES
# 2085 2019-07-08 19:28:00  19-01780         MOTOR VEHICLE THEFT
# 2086 2019-07-08 20:06:00  19-01781                        RAPE
# 2087 2019-07-08 20:09:00  19-01779          ALL OTHER OFFENSES
# 2088 2019-07-08 21:43:00  19-01783               LARCENY/THEFT
# 2089 2019-07-08 22:19:00       NaN          DISORDERLY CONDUCT
#
#                                                Incident  \
# 0                                          TRAFFIC STOP
# 1                                          TRAFFIC STOP
# 2                                          TRAFFIC STOP
# 3                               CHECK WELFARE- 911 CALL
# 4                                    SUSPICIOUS VEHICLE
# 5                                          SUSPECT STOP
# 6                         OUTSIDE ASSIST -MISCELLANEOUS
# 7                             CAMPUS CONDITION -GROUNDS
# 8                            SUSPICIOUS PERSON - REPORT
# 9                                         WELFARE CHECK
# 10    TRESPASS - REAL PROP OR STRUCTURE W/OUT OWNER ...
# 11                             PETTY THEFT -BIKE REPORT
# 12                               VEHICLE CODE VIOLATION
# 13                               VIOLATION OF PROBATION
# 14                               VEHICLE CODE VIOLATION
# 15                              CHECK WELFARE- 911 CALL
# 16                                    SUSPICIOUS PERSON
# 17                                         TRAFFIC STOP
# 18                                        WELFARE CHECK
# 19                              CHECK WELFARE- 911 CALL
# 20                                       RULE VIOLATION
# 21                                  PETTY THEFT -REPORT
# 22                              CHECK WELFARE- 911 CALL
# 23                        FRAUDULENT USE OF CREDIT CARD
# 24                        OUTSIDE ASSIST -MISCELLANEOUS
# 25                             PETTY THEFT -BIKE REPORT
# 26                                  PETTY THEFT -REPORT
# 27                                        WELFARE CHECK
# 28                              CHECK WELFARE- 911 CALL
# 29                               VEHICLE CODE VIOLATION
# ...                                                 ...
# 2060                                       SUSPECT STOP
# 2061                             VIOLATION OF PROBATION
# 2062                                  FURNISH TRANSPORT
# 2063                      FRAUDULENT USE OF CREDIT CARD
# 2064                                  SUSPICIOUS PERSON
# 2065                           PETTY THEFT -BIKE REPORT
# 2066                         POSS KNIFE ON UNIV GROUNDS
# 2067                                 SUSPICIOUS VEHICLE
# 2068                                       TRAFFIC STOP
# 2069                            CHECK WELFARE- 911 CALL
# 2070                            CHECK WELFARE- 911 CALL
# 2071  TRESPASS - REAL PROP OR STRUCTURE W/OUT OWNER ...
# 2072                                       LOST UC KEYS
# 2073                                GRAND THEFT -REPORT
# 2074                           PETTY THEFT -BIKE REPORT
# 2075                                       TRAFFIC STOP
# 2076                                    EMERGENCY ALARM
# 2077                   SUSPICIOUS CIRCUMSTANCE - REPORT
# 2078                            CHECK WELFARE- 911 CALL
# 2079                   SUSPICIOUS CIRCUMSTANCE - REPORT
# 2080                                     FOUND PROPERTY
# 2081                                  SUSPICIOUS PERSON
# 2082                                       SUSPECT STOP
# 2083                         CAMPUS CONDITION -ELEVATOR
# 2084                               DISTURBING THE PEACE
# 2085                                      VEHICLE THEFT
# 2086                                       RAPE -REPORT
# 2087                                    MISD. HIT & RUN
# 2088                           PETTY THEFT -BIKE REPORT
# 2089                                            LODGING
#
#                       Location  \
# 0                   CHANN BOWD
# 1            DURANT IFO UNIT-1
# 2          BANC IFO BANWAY LOT
# 3               UNIT-1 DEUTSCH
# 4             LIBERTY SHIP WAY
# 5                          MLK
# 6        OAKRIDGE RD/TUNNEL RD
# 7                 PEOPLES PARK
# 8                 ALUMNI HOUSE
# 9                  WARREN HALL
# 10             UNIVERSITY HALL
# 11                REC SPRT FAC
# 12                 I HOUSE LOT
# 13               SPIEKER PLAZA
# 14                        UCPD
# 15             300 GOODING WAY
# 16                         BWW
# 17        BANROFT IFO ESHELMAN
# 18                 BOWLES HALL
# 19          UNIT-3 SPENS/BLACK
# 20          1995 UNIVERSITY AV
# 21      UPPER HEARST STRUCTURE
# 22              MEMORIAL GLADE
# 23             ZELLERBACH HALL
# 24             OHLONE/WEST END
# 25        1608 1608 4TH STREET
# 26                UNIT-2 TOWLE
# 27                  EVANS HALL
# 28          HEARST FIELD ANNEX
# 29             735 GOODING WAY
# ...                        ...
# 2060                       MLK
# 2061                       MLK
# 2062                      UCOP
# 2063                       CSS
# 2064             HAAS PAVILION
# 2065             HAAS PAVILION
# 2066    GOLDEN BEAR REC CENTER
# 2067       CKC LOT NEAR BLDG 4
# 2068               1ST LECONTE
# 2069           UNIT-3 PRIESTLY
# 2070             HAAS PAVILION
# 2071             2927 DERBY ST
# 2072                   UNKNOWN
# 2073  VALLEY LIFE SCIENCE BLDG
# 2074           435 GOODING WAY
# 2075        DURANT W/ELLSWORTH
# 2076     LIFE SCIENCE ADDITION
# 2077                      UCOP
# 2078             HAVILAND HALL
# 2079  VALLEY LIFE SCIENCE BLDG
# 2080                       MLK
# 2081           UNIVERSITY HALL
# 2082           UNIVERSITY HALL
# 2083             UNIT-3 NORTON
# 2084                SOUTH HALL
# 2085            OPTOMETRY LANE
# 2086          ROCHDALE VILLAGE
# 2087             UNDERHILL LOT
# 2088        LOWER SPROUL PLAZA
# 2089             DWINELLE HALL
#
#                                                Synopsis  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    OCCURRED: 05/8/19 0848 HOURS (FX-24-S) REPORTS...
# 12                                                  NaN
# 13    OCCURRED: 05/8/19 1056 HOURS WHITMORE, HENRY (...
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21    OCC: 05/7/19 0920 - 1018 HOURS (FW-46-E) REPOR...
# 22                                                  NaN
# 23    5/2/19 - 05/18/19, UNKNOWN TIME (MXA-E) REPORT...
# 24                                                  NaN
# 25                                                  NaN
# 26    05/3/19 0000 - 05/4/19 2330 HOURS (MA-18-S) RE...
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2060                                                NaN
# 2061  OCCD 07/08/2019, 0745 HRS BEJAMIN, STEPHAN (MB...
# 2062                                                NaN
# 2063                                                NaN
# 2064                                                NaN
# 2065  OCCD 06/30/2019 - 07/08/2019, 1800 - 0909 HRS ...
# 2066  OCCD 07/07/2019, 1106 HRS HAMMOND, BLAKE (MW-2...
# 2067                                                NaN
# 2068                                                NaN
# 2069                                                NaN
# 2070                                                NaN
# 2071  OCCD 7/8/19, 1311 HRS REPORT OF A TRESPASSER, ...
# 2072  OCCD 08/18/2017 - 06/27/2019 (MAA-S) REPORTS T...
# 2073  OCCD 7/8/19, 1410 - 1415 HRS (MW-20-S) REPORTS...
# 2074  OCCURED: 07/06/19 1000-07/08/19 0800. (FW-27-O...
# 2075                                                NaN
# 2076                                                NaN
# 2077  OCCD 7/8/19, 1634 HRS (MWA-E) REPORTS SUSPICIO...
# 2078                                                NaN
# 2079                                                NaN
# 2080  OCCURED: 07/08/19 1805 FOUND KNIFE, MLK MENS R...
# 2081                                                NaN
# 2082                                                NaN
# 2083                                                NaN
# 2084                                                NaN
# 2085  OCCURRED: 07/08/19 1940 HRS. (MH-17-O) AND (MH...
# 2086  OCC 7/6/2019 FEMALE SURVIVOR REPORTS SEXUAL AS...
# 2087  OCCURED: 04/20/19 1103. (MA-21-O) IDENTIFIED A...
# 2088  OCC 7/8/2019 1830-2140 (FA-23-S) REPORTS THEFT...
# 2089                                                NaN
#
#                     Disposition
# 0                WARNING ISSUED
# 1            CLOSED BY CITATION
# 2            CLOSED BY CITATION
# 3                        CLOSED
# 4                        CLOSED
# 5     FIELD IDENTIFICATION CARD
# 6                        CLOSED
# 7                        CLOSED
# 8     FIELD IDENTIFICATION CARD
# 9                        CLOSED
# 10    FIELD IDENTIFICATION CARD
# 11          UNDER INVESTIGATION
# 12                       CLOSED
# 13             CLOSED BY ARREST
# 14                       CLOSED
# 15                       CLOSED
# 16                    UNFOUNDED
# 17               WARNING ISSUED
# 18                       CLOSED
# 19                       CLOSED
# 20                       CLOSED
# 21          UNDER INVESTIGATION
# 22                       CLOSED
# 23          UNDER INVESTIGATION
# 24                       CLOSED
# 25                    CANCELLED
# 26          UNDER INVESTIGATION
# 27                       CLOSED
# 28                       CLOSED
# 29           CLOSED BY CITATION
# ...                         ...
# 2060                     CLOSED
# 2061           CLOSED BY ARREST
# 2062                     CLOSED
# 2063                  CANCELLED
# 2064                     CLOSED
# 2065        UNDER INVESTIGATION
# 2066           CLOSED BY ARREST
# 2067         CLOSED BY CITATION
# 2068             WARNING ISSUED
# 2069                     CLOSED
# 2070                     CLOSED
# 2071        UNDER INVESTIGATION
# 2072        UNDER INVESTIGATION
# 2073        UNDER INVESTIGATION
# 2074        UNDER INVESTIGATION
# 2075             WARNING ISSUED
# 2076                     CLOSED
# 2077        UNDER INVESTIGATION
# 2078                     CLOSED
# 2079                     CLOSED
# 2080        UNDER INVESTIGATION
# 2081                     CLOSED
# 2082                     CLOSED
# 2083                     CLOSED
# 2084                     CLOSED
# 2085           CLOSED BY ARREST
# 2086        UNDER INVESTIGATION
# 2087        UNDER INVESTIGATION
# 2088        UNDER INVESTIGATION
# 2089                     CLOSED
#
# [2090 rows x 7 columns]

# %%
# Check all records imported.
len(df)
# Out:
# 2090

# %%
# Check types, especially date imports okay.
df.dtypes
# Out:
# Date           datetime64[ns]
# Case                   object
# Category               object
# Incident               object
# Location               object
# Synopsis               object
# Disposition            object
# dtype: object

# %%
# Set up googlemaps API
# pip install -U googlemaps
import googlemaps
from datetime import datetime

file = open(“keyfile”, “r”) 

gmaps = googlemaps.Client(key=file.read())

# %%
# Define some helpers for geocoding.

def getaddress(raw):
    """
    Look up an address in Berkeley. 
    """
    return gmaps.geocode(str(raw) + ", Berkeley, CA")

def getaddressll(ll):
    """
    Get the address for a lat/long pair.
    """
    try:
        location = tuple(map(float, str.split(ll[1:-1:],",")))
    except:
        return None
    return gmaps.reverse_geocode(location)

# %%
# Populate a new column with Google-parsed addresses.
df["gmaps Address"] = df["Location"].apply(getaddress)
#test_df["gmaps AddressLL"] = test_df["Location"].apply(getaddressll)

# %%
# Where the Location was missing, use the geocode data to fill it in.

def latlng_from_gm_address(gm):
    if(not gm):
        return None
    
    return "(" + \
    str(gm[0]["geometry"]["location"]["lat"]) + ", " + \
    str(gm[0]["geometry"]["location"]["lng"]) + ")"

df['LatLng'] = df["gmaps Address"].apply(latlng_from_gm_address)

def formatted_from_gm_address(gm):
    if(not gm):
        return None
    
    return str(gm[0]["formatted_address"])

df['Address'] = df["gmaps Address"].apply(formatted_from_gm_address)

# %%
print(len(df['Address'].value_counts()))
# Out:
# 447

# %%
# Plot the frequency of location names
df['Address'].value_counts()[0:20].plot.bar(title="Location Names Pre-Grouping")

# %%
# Set up a blank Google Map plot, centred on St Paul.
# pip install gmplot
from gmplot import gmplot

#del(gmap)
gmap = gmplot.GoogleMapPlotter(37.8715226, -122.273042, 13)

# %%
# Get a list of the lat/long pairs.
latlongs = [tuple(map(float, str.split(location[1:-1:],","))) for location in list(df["LatLng"]) if type(location) is str ]

# %%
# Get lats/longs lists and generate heatmap.
dflats, dflons = zip(*latlongs)
gmap.heatmap(dflats, dflons, radius= 100, threshold=5, dissipating= True)

# Loop through the rows and put a marker for each graffiti instance,
# colour/label is based on the group name.
for index, row in df.iterrows():
    
    try:
        location = tuple(map(float, str.split(row["LatLng"][1:-1:],",")))
    except:
        continue
    
    gmap.marker(location[0], location[1])

# %%
# Plot the map.
gmap.draw("map.html")

# %%
# Save the clean dataset.
df.to_pickle("ucbcrime0.pickle")

# %%
df.to_csv("out_geo.csv")
